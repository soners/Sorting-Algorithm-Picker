# %%
import pandas as pd

# %%
df = pd.DataFrame.from_csv('data/data.csv')
# Out:
# /home/ycb_stm/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#            chosen  consecutive_inversion  deviation_of_digits  \
# 0      radix_sort               0.532338             0.520656
# 1      quick_sort               0.485997             0.000000
# 2  insertion_sort               0.333333             0.000000
# 3      quick_sort               0.479508             0.469347
# 4      merge_sort               0.479401             0.625883
#
#    deviation_of_digits_base_2  deviation_of_duplicates  expectation_of_digits  \
# 0                    1.538110                 0.000351               4.636816
# 1                    0.818066                 0.000164               5.000000
# 2                    0.000000                 0.000000               5.000000
# 3                    1.750705                 0.000000               4.750000
# 4                    1.705556                 0.000229               4.524345
#
#    expectation_of_digits_base_2  expectation_of_duplicates  inversion  length  \
# 0                     14.149254                   0.005000   0.460945     201
# 1                     15.696870                   0.001664   0.495142     607
# 2                     16.000000                   0.333333   0.333333       3
# 3                     15.024590                   0.004098   0.489408     244
# 4                     13.745318                   0.003759   0.502239     267
#
#    max_digit  max_digit_base_2  max_duplicate  min_digit  min_digit_base_2  \
# 0          5                16       0.009950          3                 8
# 1          5                17       0.003295          5                14
# 2          5                16       0.333333          5                16
# 3          5                17       0.004098          3                 9
# 4          5                16       0.007491          2                 7
#
#    min_duplicate
# 0       0.004975
# 1       0.001647
# 2       0.333333
# 3       0.004098
# 4       0.003745

# %%
# model will handle one hot encoding by having 6 neurons(1 for each algorithm) at the last layer
mapping = {
    'radix_sort': 0,
    'count_sort': 1,
    'merge_sort': 2,
    'heap_sort': 3,
    'quick_sort': 4,
    'insertion_sort': 5,
}

results = df.values

for i in range(len(df.values)):
    results[i][0] = mapping[df.values[i][0]]

# %%
new_df = pd.DataFrame(results, columns=df.columns)
new_df.to_csv('data/onehot_encoded.csv')
